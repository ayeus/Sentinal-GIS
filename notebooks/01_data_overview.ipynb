# %%
import geopandas as gpd
import pandas as pd

# Load data
gdf = gpd.read_file("../data/processed/india_dengue_state_year.geojson")

# Basic info
print(gdf.shape)
print(gdf.columns)

# Check CRS
print("CRS:", gdf.crs)

# Check missing values
gdf.isna().sum()

# Basic statistics
gdf[['cases', 'deaths']].describe()
# Out:
# (151, 16)
# Index(['GID_1', 'GID_0', 'COUNTRY', 'state_std', 'VARNAME_1', 'NL_NAME_1',
#        'TYPE_1', 'ENGTYPE_1', 'CC_1', 'HASC_1', 'ISO_1', 'state', 'year',
#        'cases', 'deaths', 'geometry'],
#       dtype='object')
# CRS: EPSG:4326
#        cases deaths
# count    132    132
# unique   124     26
# top        0      0
# freq       3     74
