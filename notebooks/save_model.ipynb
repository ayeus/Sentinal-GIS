# %%
import joblib

joblib.dump(rf_spatial, "../backend/model/rf_spatial.pkl")
joblib.dump(le, "../backend/model/label_encoder.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import joblib
# ----> 3 joblib.dump(rf_spatial, "../backend/model/rf_spatial.pkl")
#       4 joblib.dump(le, "../backend/model/label_encoder.pkl")
#
# NameError: name 'rf_spatial' is not defined
